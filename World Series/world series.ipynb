# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('world_series_ratings.csv')

# %%
df.head()
# Out:
#    Year Network  Telecasts  Rating  Share   avg_homes  avg_viewers  \
# 0  2007     FOX        4.0    10.6   18.0  11994000.0   17123000.0
# 1  2006     FOX        5.0    10.1   17.0  11282000.0   15812000.0
# 2  2005     FOX        4.0    11.1   19.0  12272000.0   17162000.0
# 3  2004     FOX        4.0    15.8   26.0  17270000.0   25390000.0
# 4  2003     FOX        6.0    12.8   22.0  13834000.0   20142000.0
#
#    cost_per_spot               winners               losers
# 0            NaN       Boston Red Sox      Colorado Rockies
# 1       399025.0  St. Louis Cardinals        Detroit Tigers
# 2       395000.0     Chicago White Sox       Houston Astros
# 3       375000.0        Boston Red Sox  St. Louis Cardinals
# 4       298983.0      Florida Marlins            NY Yankees

# %%
df.corr()
# Out:
#                    Year  Telecasts    Rating     Share  avg_homes  \
# Year           1.000000  -0.321531 -0.804174 -0.962549  -0.777111
# Telecasts     -0.321531   1.000000  0.436504  0.412986   0.453119
# Rating        -0.804174   0.436504  1.000000  0.891404   0.936616
# Share         -0.962549   0.412986  0.891404  1.000000   0.894288
# avg_homes     -0.777111   0.453119  0.936616  0.894288   1.000000
# avg_viewers   -0.839976   0.454839  0.967399  0.938904   0.978878
# cost_per_spot  0.877881  -0.496462 -0.876560 -0.892059  -0.825094
#
#                avg_viewers  cost_per_spot
# Year             -0.839976       0.877881
# Telecasts         0.454839      -0.496462
# Rating            0.967399      -0.876560
# Share             0.938904      -0.892059
# avg_homes         0.978878      -0.825094
# avg_viewers       1.000000      -0.860496
# cost_per_spot    -0.860496       1.000000

# %%
sns.heatmap(df.corr(), annot=True, cmap='magma')
# Out:
# <AxesSubplot:>
